# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌بینی قیمت خانه‌ها
# </font>
# </h1>
#
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در این تمرین قصد داریم تاثیر <b>پیش‌پردازش و مدیریت داده‌ها</b> را روی کیفیت پیش‌بینی یک مدل بررسی کنیم.
# برای این کار از مجموعه داده‌ای که شامل اطلاعاتی در مورد ویژگی خانه‌ها و قیمت فروش آن‌هاست استفاده می‌کنیم.
# ابتدا مدل را روی داده خام بدون پیش‌پردازش آموزش می‌دهیم و سپس پس از اعمال یک سری تکتیک‌های پیش پردازش دوباره مدل را آموزش می‌دهیم و نتایج را با هم مقایسه می‌کنیم.
# </font>
# </p>
#
#
# <h2 dir=rtl align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#  فایل ‌<code>ames_housing.csv</code> شامل نمونه‌های آموزشی است.
# ستون <code>SalePrice</code> متغیر هدف بوده و سایر ستون‌ها ویژگی‌های خانه را نمایش می‌دهند.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# | <b>ستون</b> | <b>توضیحات</b> |
# | :---: | :--- |
# | <code>SalePrice</code> | قیمت فروش خانه |
# | <code>LotFrontage</code> | طول جلوی خانه که به خیابان متصل است (بر حسب فوت) |
# | <code>LotArea</code> | مساحت کل زمین خانه (بر حسب فوت مربع) |
# | <code>OverallQual</code> | کیفیت کلی خانه (مقیاس ۱ تا ۱۰) |
# | <code>GrLivArea</code> | مساحت فضای قابل سکونت روی زمین (بر حسب فوت مربع) |
# | <code>TotalBsmtSF</code> | مساحت کل زیرزمین (بر حسب فوت مربع) |
# | <code>HouseStyle</code> | نوع معماری خانه (یک‌طبقه، دو‌طبقه، Split-Level و ...) |
# | <code>CentralAir</code> | داشتن یا نداشتن سیستم تهویه مرکزی (<code>Y</code> یا <code>N</code>) |
# | <code>Neighborhood</code> | محله‌ای که خانه در آن قرار دارد |
#
# </font>
# </div>
# </center>

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# با استفاده از روش‌هایی که در درسنامه یاد گرفته‌اید، به‌کمک کتابخانه‌ی <code>pandas</code> این مجموعه‌داده را از فایل بارگیری کرده و در دیتافریم <code>df</code> ذخیره کنید.
# </font>
# </p>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("") #TODO
print(df.head())

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# از آنجایی که فعلا نمی‌خواهیم پیش پردازش خاصی انجام دهیم، فقط ستون‌هایی که به صورت عددی هستند را برای پیش بینی به مدل می‌دهیم. برای اینکار ابتدا ستون‌های عددی را مشخص کنید و سپس ردیف‌هایی که دارای مقادیر گم شده هستند را حذف کنید.
# (دلیل جدا کردن ستون‌های عددی و حذف مقادیر گم شده این است که مدل در صورتی که مقادیر غیر عددی یا گم شده به آن بدهیم دچار خطا می‌شود. )
# </font>
# </p>

# %%
# TODO: specify numinol columns


# TODO: Drop NaN rows to allow model training

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# در اینجا ابتدا مجموعه داده‌مان را به دو مجموعه train و test تقسیم می‌کنیم. سپس مدل رگرسیون خطی‌ را برای پیش بینی قیمت خانه پیاده سازی می‌کنیم.
# </font>
# </p>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(
    X_raw, y_raw, test_size=0.2, random_state=42
)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred_raw = model.predict(X_test)

mse_raw = mean_squared_error(y_test, y_pred_raw)
print("MSE before preprocessing:", mse_raw)
# Out:
# MSE before preprocessing: 16.724016979678417

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# MSE میانگین مجذور اختلاف نمونه‌های واقعی با نمونه پیش بینی شده توسط مدل است.
# هرچقدر این اختلاف کمتر باشد، یعنی مدل به درستی آموزش دیده و پیش بینی‌های دقیق‌تری دارد.
# حالا سراغ مقادیر گم شده برویم. در ابتدا بررسی می‌کنیم که چه ستون‌هایی مقادیر گم شده دارند.
# </font>
# </p>

# %%
#TODO

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# مقادیر گم شده ستون‌هایی که عددی هستند را با میانه و ستون‌هایی که به صورت دسته‌ای هستند را با مد پر کنید.
# </font>
# </p>

# %%
num_features = #TODO
cat_features = #TODO
# TODO: drop nan values

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# حال باید داده‌های پرت مجموعه داده را حذف کنید. با توجه به معیار IQR هر ستون، داده‌های پرت همان ستون را حذف کنید.
# </font>
# </br>
# <font face="vazir" size=3>
# <b>دقت کنید که داده‌های پرت ستون هدف را
# نباید
#  حذف کنید.
# </b>
#
# </font>
# </p>

# %%
# TODO: remove outliers
def remove_outliers_iqr(df, columns=None):

    return

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# حالا ستون‌هایی که از نوع دسته‌ای هستند را با استفاده از روش binary
# encoding به صورت One_Hot تبدیل کنید.
# ستون‌های عددی را با استفاده از StandardScaler استناداردسازی کنید.
# دقت کنید که ستون هدف نباید جزو اعمال پیش پردازش باشد.</br>
# همچنین در مرحلهٔ انکودینگ، اولین ستونِ هر مجموعهٔ ستون‌های One-Hot شده را حذف کنید.
# </font>
# </p>

# %%
from sklearn.preprocessing import StandardScaler

X = # TODO
y =  # TODO


X_encoded = # TODO

scaler = StandardScaler()
X_encoded[num_features] = # TODO

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# حالا محموعه داده پیش پردازش شده را به دو مجموعه داده train و test تقسیم می‌کنیم و سپس مدل را با استفاده از مجموعه داده train آموزش می‌دهیم و مدل را روی مجموعه داده test آزمایش می‌کنیم.
# </font>
# </p>

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)


y_pred = model.predict(X_test)
mse_cleaned = mean_squared_error(y_test, y_pred)
print("MSE after preprocessing:", mse_cleaned)

# %% [markdown]
# <p dir=rtl style="direction: rtl;text-align: justify;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
# همانطور که مشاهده کردید خطا به طرز قابل توجهی کاهش یافت. اما همچنان خطا بالاست که باید با استفاده از تکنیک‌های دیگه مثل استفاده از مدل‌های پیچیده‌تر و داده بیشتر آن را کاهش داد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="direction: rtl; text-align: justify;line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# نحوه‌ی داوری
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در سامانه‌ی داوری دیتافریم <code>X_encoded</code> و راه‌حل شما مورد ارزیابی قرار می‌گیرد. بنابراین نیاز است داده‌ها را به‌درستی و طبق خواسته‌ی سوال مدیریت کرده باشید.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.</font>
# </p>

# %%
import zlib
import zipfile
import os
if not os.path.exists(os.path.join(os.getcwd(), 'buy_house.ipynb')):
    # %notebook -e buy_house.ipynb

X_encoded.to_csv('X_encoded.csv', index=True)

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

file_names = ["X_encoded.csv", "buy_house.ipynb"]
compress(file_names)
